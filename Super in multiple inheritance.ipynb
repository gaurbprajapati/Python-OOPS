# %%
class A(object):
    def __init__(self,value1):
        self.value1=value1
        print('First%d'%value1)
        super().__init__(self.value1)

class B(object):
    def ___init__(self,value2):
        self.value2=value2
        print(f"Second value {self.value2}")


class Log(A,B):
    def __init__(self,value1,value2):
        # self.a=a
        # self.b=b
        self.value1=value1
        self.value2=value2
        super().__init__(self.value1)
       

x = Log(1000,2000)

# %%
class JOB1:
    def __init__(self,sal1,**k):
        
        super().__init__(**k)
        self.sal1=sal1
        # print(self.sal1)
        # print(f"Salary of Job webdev.{self.sal1}")
    def jobone_detail(s):
        print("1. First Job name:-WEB DEVELOPER")
        # print("\n")
        print(f"1. Salary of Job webdev:--{s.sal1}")

class JOB2:
    def __init__(self,sal2,**k):
        
        super().__init__(**k)
        self.sal2=sal2
        # print(self.sal2)
        # print("Second Job name:-Data Scientist")
        # print(f"Salary of Job Data scientist{self.sal2}")
    def jobTwoDetail(s):
        print("2. Second Job name:--Data Scientist")
        # print("\n")
        print(f"2. Salary of Job Data Scientist:--{s.sal2}")

class combine(JOB1,JOB2):

    def __init__(self,a,b,name):
        self.name=name
        print(f"Name of worker who do two job simultaniously:-{self.name}")
        # print("job:-",name)
        super().__init__(sal1=a,sal2=b)
        # print(self.sal1+self.sal2)
        
    def total_salary(s):
        print(f"The total salary of {s.name} is {s.sal1+s.sal1}")

print("-------------------------------------------------------")  
c=combine(40000,50000,"Gaurv")
print("-------------------------------------------------------")
c.jobone_detail()
print("\n")
c.jobTwoDetail()
print("\n")
c.total_salary()
print("________________________________________________________")
# Out:
# -------------------------------------------------------
# Name of worker who do two job simultaniously:-Gaurv
# -------------------------------------------------------
# 1. First Job name:-WEB DEVELOPER
# 1. Salary of Job webdev:--40000
#
#
# 2. Second Job name:--Data Scientist
# 2. Salary of Job Data Scientist:--50000
#
#
# The total salary of Gaurv is 80000
# ________________________________________________________

# %%
class P1_class:
    def __init__(self,a,b):
        super().__init__(20,10)
        self.a=a
        self.b=b
    def show1(self):
        print(f"Value of a and b {self.a} and {self.b}")

class P2_class:
    def __init__(self,c,d):
        self.c=c
        self.d=d
    def show2(s):
        print(f"The value of c and D is {s.c} and {s.d}")

class Child(P1_class,P2_class):
    def __init__(self,e):
        self.e=e
        super().__init__(12,30)
    def display(s):
        print(f'the value of E is {s.e}')
    def sum(s):
        print(f'The sum of number is {s.a+s.b+s.c+s.d+s.e}')
    
o =Child(5)
o.show1()
o.show2()
o.display()
o.sum()
# Out:
# Value of a and b 12 and 30
# The value of c and D is 20 and 10
# the value of E is 5
# The sum of number is 77

# %%
class P1_class:
    def __init__(self,a,b):
        super().__init__(self.c,self.d)
        self.a=a
        self.b=b
    def show1(self):
        print(f"Value of a and b {self.a} and {self.b}")

class P2_class:
    def __init__(self,c,d):
        self.c=c
        self.d=d
    def show2(s):
        print(f"The value of c and D is {s.c} and {s.d}")

class Child(P1_class,P2_class):
    def __init__(self,e,a,b,c,d):
        self.e=e
        self.a=a
        self.b=b
        self.d=d
        self.c=c
        super().__init__(self.a,self.b)
    def display(s):
        print(f'the value of E is {s.e}')
    def sum(s):
        print(f'The sum of number is {s.a+s.b+s.c+s.d+s.e}')
    
o =Child(1,2,3,4,5)
o.show1()
o.show2()
o.display()
o.sum()

# %%
class P1_class:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def show1(self):
        print(f"Value of a and b {self.a} and {self.b}")

class P2_class:
    def __init__(s,c,d):
        s.c=c
        s.d=d
    def show2(s):
        print(f"The value of c and D is {s.c} and {s.d}")

class Child(P1_class,P2_class):
    def __init__(self,e,a,b,c,d):

        P1_class.__init__(self,a,b)
        P2_class.__init__(self,c,d)
        self.e=e
    def display(s):
        print(f'the value of E is {s.e}')
    def sum(s):
        print(f'The sum of number is {s.a+s.b+s.c+s.d+s.e}')
    
o =Child(1,2,3,4,5)
o.show1()
o.show2()
o.display()
o.sum()

# %%
class P1_class:
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def show1(self):
        print(f"Value of a and b {self.a} and {self.b}")

class P2_class:
    def __init__(s,c,d):
        s.c=c
        s.d=d
    def show2(s):
        print(f"The value of c and D is {s.c} and {s.d}")

class Child(P1_class,P2_class):
    def __init__(self,e,a,b,c,d):

        P1_class.__init__(self,10,20)
        P2_class.__init__(self,30,40)
        self.e=e
    def display(s):
        print(f'the value of E is {s.e}')
    def sum(s):
        print(f'The sum of number is {s.a+s.b+s.c+s.d+s.e}')
    
o =Child(1,2,3,4,5)
o.show1()
o.show2()
o.display()
o.sum()

# %%
class parent:
    def __init__(self,n,roll):
        print("Detail of student:--")
        self.n=n
        self.roll=roll
        # self.m1=0
        # self.m2=0
        self.m1=int(input())
        self.m2=int(input())
    def D(self):
     
        print("Name",self.n)
        print("Roll",self.roll)
        print("Parent 1 marks",self.m1+self.m2)

class  parent2:
    def __init__(self,roll2) -> None:
        print("parent 2------")
        self.roll2=roll2
        # self.m3=0
        # self.m4=0
        self.m3=int(input())
        self.m4=int(input())
    def D2(self):
        print("Rool 2----",self.roll2)
       
        print("Parent 2 marks",self.m4+self.m3)
        

class child(parent,parent2):
    def __init__(self,n,roll,roll2):
        parent.__init__(self,n,roll)
        parent2.__init__(self,roll2)
        print("Child class:----")
        print("Tollal rooll number:=====",self.roll2+self.roll)
        
        print("Total marks of chilh class :---",self.m4+self.m3+self.m1+self.m2)



o = child("h",88888,7)
o.D()
o.D2()
